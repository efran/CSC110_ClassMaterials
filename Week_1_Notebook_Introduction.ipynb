# %% [markdown]
# # Welcome to CSC 110!
#
# This class will provide you with an introduction to Python and to programming in general. <br>
# I hope you enjoy the class and learn a lot! <br>
# Please let me know __*RIGHT AWAY*__ if you are having trouble with anything -- we will work together to fix any and all problems!

# %% [markdown]
# <img src="EGAN.png" width="100" style="margin: 5px 50px 0px 50px; width: 200px; float: left;" title="Emilia Gan" alt="EGAN.png" /> So -- to introduce myself. By now, you should know that I am Emilia Gan. I just finished my first year in the Computer Science PhD program at the <a href="https://www.cs.washington.edu/">Paul G. Allen School of Computer Science & Engineering</a> at the University of Washington, Seattle. Before starting this program, I was a graduate student in the <a href="https://globalhealth.washington.edu/education-training/phd-pathobiology">Pathobiology Program</a> (also at UW, and I taught computer science (here at SSC) and statistics (at Seattle Central and Bellevue Colleges) part-time. <br><br> This summer, in addition to teaching this class, I am interning part-time at <a href="https://code.org">Code.org</a> and I am doing research with the <a href="https://wiki.communitydata.cc/Main_Page">Community Data Science Collective</a> at UW. My research involves studying how people learn to program on the <a href="https://scratch.mit.edu/">Scratch</a> online programming website.

# %% [markdown]
# ---
#
# ---
# This document is an example of a **Jupyter Notebook**. We will be using Jupyter Notebooks for our HW assignments. If you know HTML (or if you want to learn some), you can make your notebooks look very pretty. However, this is <u>NOT NECESSARY</u>. I will be happy with FUNCTIONAL notebooks. Plain text entered into a Markdown cell will be sufficient for any written components of an assignment. <br>
# It will be useful to know how to include images in your notebooks. If you store the images locally with your Jupyter Notebook file, you can include an image by using the following command:<br><br>

# %% [markdown]
# <img src="image_command.png">

# %% [markdown]
# The great thing about Jupyter Notebooks is that you can include runnable code in your notebooks. This cell is a "Markdown" cell, and produces nicely formatted text for reading. The cell below this one will contain your first "program" -- a line of runnable Python code. To run the code, press __Ctrl-Enter__ (this will run the code without advancing to the next cell) or press __Shift-Enter__ (this will run the code and advance to the next cell).<br><br>
#
# ---
#
# ---

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# You will see that The text between the parentheses got displayed as output. You will learn other ways to create and run programs, but the ability to run blocks of text like this within the notebook is very convenient. If you ever want to __clear__ the displayed output, click on the "_Cell_" tab at the top of the page and select "_All Output_" followed by "_Clear_."

# %% [markdown]
# <img src="HateReadingYourCode.png" width="100" style="margin: 0px 50px 5px 50px; width: 125px; float: right;" title="BadCode" alt="HateReadingYourCode.png" /> Formatting is very important! Code that is not formatted correctly may not run! Even when code runs, code that is easy to read is easier to understand and maintain. You will need to read "legacy" code at some point (code that you are not creating from scratch). Even if that code was written by __YOU__ sometime in the past, good style and formatting will make the code easier to work with. You do not want me feeling like this while I am reading your code, trust me. <br>
#
# While I do not require you to follow any particular style, there are some important guidelines to keep in mind. <br>
# - __INDENTATION__ is critical in python (We will discuss this more later)
# - It is useful to leave HUMAN-READABLE notes in your programs (known as "_comments_")
# - There is a useful style guide <a href="http://courses.cs.washington.edu/courses/cse160/16wi/handouts/style_guide.html">HERE</a> that you can use, but do not consider this the ONLY right way to format your code.
# <br><br><br>
# If you want to see the full xkcd comic, look <a href="https://xkcd.com/1695/">HERE</a>.

# %%
# THIS IS A COMMENT. It is intended for HUMAN readers and is ignored by the computer.
# <- You indicate a comment line with the hashtag (or pound sign) symbol

# We will now look at some code that demonstrates the importance of correct formatting.

# This code runs properly:
print ("Hello World")
# Out:
# Hello World

# %%
# This code does not. The second line of code has incorrect indentation.
# Run the code to see what happens.
print ("Hello World")
 print ("I like CS")
# Out:
#   File "<ipython-input-20-beb02b926e74>", line 4
#     print ("I like CS")
#     ^
# IndentationError: unexpected indent

# %%
'''
This is another way to add comments. The hashtag/pound sign comments ONE line.
This method creates a comment BLOCK of one or more lines.
The extra space before the second line above is an example of an indentation error.
The code below has a SYNTAX error that prevents it from running properly:
'''
# Run the code to see what happens.
print "Hello World"
# Out:
#   File "<ipython-input-21-e1fd9615c58a>", line 8
#     print "Hello World"
#                       ^
# SyntaxError: Missing parentheses in call to 'print'

# %% [markdown]
# As you can see, when you make errors in your code, Python tries to give you clues as to what went wrong in the form of error messages. You can correct the errors and re-run the cells in the notebook.
# <br><br>
# I hope this short introduction has convinced you of the usefulness of Jupyter notebooks. <br><br>In addition to code, images, and text, you can even include videos in your Jupyter Notebooks.<br>
# The short video embedded in the cell below is from <a href="https://code.org">Code.org</a>. It is optional, but does a nice job introducing programming and describing some of the many applications of computer science:
#
# (If the video is not playing for you properly, it can also be viewed <a href="https://www.youtube.com/watch?v=QvyTEx1wyOY">HERE</a>.)

# %%
# You need to run this cell using Shift-Enter or Ctrl-Enter in order to see the video.
from IPython.display import YouTubeVideo
YouTubeVideo('QvyTEx1wyOY')

# %% [markdown]
# The next Jupyter Notebook I share with you will contain more code cells and get you started interacting with Python more. <br>But now ... it's __YOUR TURN__.<br><br>
# __For HW 1 Part 1__:
# - create a Jupyter Notebook titled: Week_1_YOUR_NAME_Intro (replace YOUR_NAME with your first name and your last name)
# - include a recent photo of yourself (you will need to send me the photo file as well, so that it will display for me) when I open and run your notebook.
# - A biographical sketch:
#     - Where are you enrolled? (e.g. Are you a South Seattle student or are you just taking one summer class here?)
#     - What is your major?
#     - What are you hoping to learn from this class?
#     - Anything else you feel like sharing (e.g. some things you like, something interesting you did recently, etc.)
